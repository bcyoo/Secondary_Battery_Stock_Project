# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 데이터 수집방법

# %%
# ##2차전지 특허 파일 다운로드

# !pip3 install selenium
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# from bs4 import BeautifulSoup 
# import time
# import urllib


# #크롬창 열기
# driver = webdriver.Chrome('./chromedriver.exe')

# ## 키프리스 접속.

# url = 'http://kpat.kipris.or.kr/kpat/searchLogina.do?next=MainSearch#page1'
# driver.get(url)
# time.sleep(5)
# driver.implicitly_wait(10)   ## 10초를 기다리는데 웹페이지가 로딩되면 다음으로 넘어감.
# driver.find_element_by_xpath('//*[@id="queryText"]').send_keys('이차전지+2차셀+2차쎌+2차전지+"SECONDARY BATTERY"+"SECONDARY CELL"+"secondary battery"+"secondary cell"+세컨더리셀+"이차 전지"+이차셀')
# driver.find_element_by_xpath('//*[@id="SearchPara"]/fieldset/span[1]/a/img').click()
# driver.find_element_by_xpath('//*[@id="chkSelItemAll"]').click()
# driver.find_element_by_xpath('//*[@id="detail_content"]/div[1]/div[2]/span[3]/a').click()

# %%
## 2차전지 csv 파일 불러오기.
df = pd.read_csv('./secondary_cell_AUTHOR_RECODED.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63963 entries, 0 to 63962
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID              63915 non-null  object
#  1   DATE            63879 non-null  object
#  2   TITLE           63879 non-null  object
#  3   AUTHOR          63879 non-null  object
#  4   AUTHOR_RECODED  63879 non-null  object
# dtypes: object(5)
# memory usage: 2.4+ MB

# %%
## 삼성전자 columns 접근
df[df['AUTHOR'].str.contains('삼성전자',na=False)]
# Out:
#          ID        DATE                                              TITLE  \
# 37       38  2018.11.21  전고체 이차 전지 및 그 충전 방법(ALL-SOLID-STATE SECONDARY ...
# 156     157  2018.10.19  이차전지용 음극활물질, 이차전지용 도전성 조성물, 이를 포함하는 음극재료, 이를 포...
# 165     166  2017.08.08  이차전지 및 이차전지의 제조방법(Secondary battery and method...
# 168     169  2012.12.27  이차전지용 음극활물질, 이차전지용 도전성 조성물, 이를 포함하는 음극재료, 이를 포...
# 209     210  2017.06.22  3차원 전극구조체 및 이를 포함하는 이차전지(Three-dimensional ele...
# ...     ...         ...                                                ...
# 63902  3819  2003.08.18  개선된 구조적 안정성 및 향상된 캐패시턴스를 갖는캐패시터를 포함하는 반도체 장치 및...
# 63910  3827  2003.02.19  무기 분말의 코팅방법 및 이에 의하여 제조된 코팅된무기입자(Method for co...
# 63921  3838  2002.02.12  기판 사이에 배치된 중합 개시 및 강화 요소로 구성된전기광학식 디스플레이(ELECT...
# 63924  3841  2002.11.20  실리콘 광소자 및 이를 적용한 화상 입출력장치(Silicon optoelectron...
# 63961  3878  2010.07.21  비주얼 페어링 수행 시스템 및 방법(SYSTEM AND METHOD FOR VISU...
#
#                          AUTHOR            AUTHOR_RECODED
# ...

# %%
## 삼성전자 Data Frame 생성
df_samsung_electron = df[df['AUTHOR'].str.contains('삼성전자', na=False)]
df_samsung_electron
# Out:
#          ID        DATE                                              TITLE  \
# 37       38  2018.11.21  전고체 이차 전지 및 그 충전 방법(ALL-SOLID-STATE SECONDARY ...
# 156     157  2018.10.19  이차전지용 음극활물질, 이차전지용 도전성 조성물, 이를 포함하는 음극재료, 이를 포...
# 165     166  2017.08.08  이차전지 및 이차전지의 제조방법(Secondary battery and method...
# 168     169  2012.12.27  이차전지용 음극활물질, 이차전지용 도전성 조성물, 이를 포함하는 음극재료, 이를 포...
# 209     210  2017.06.22  3차원 전극구조체 및 이를 포함하는 이차전지(Three-dimensional ele...
# ...     ...         ...                                                ...
# 63902  3819  2003.08.18  개선된 구조적 안정성 및 향상된 캐패시턴스를 갖는캐패시터를 포함하는 반도체 장치 및...
# 63910  3827  2003.02.19  무기 분말의 코팅방법 및 이에 의하여 제조된 코팅된무기입자(Method for co...
# 63921  3838  2002.02.12  기판 사이에 배치된 중합 개시 및 강화 요소로 구성된전기광학식 디스플레이(ELECT...
# 63924  3841  2002.11.20  실리콘 광소자 및 이를 적용한 화상 입출력장치(Silicon optoelectron...
# 63961  3878  2010.07.21  비주얼 페어링 수행 시스템 및 방법(SYSTEM AND METHOD FOR VISU...
#
#                          AUTHOR            AUTHOR_RECODED
# ...

# %%
## 삼성전자 종목코드 colums 생성 , '005930' values 생성
df_samsung_electron['종목코드'] = '005930'
# Out:
# <ipython-input-83-ea7aa3f27732>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samsung_electron['종목코드'] = '005930'

# %%
## DATE columns을  pd.to_datetime를 통해 datetime type 변경
df_samsung_electron['DATE'] = pd.to_datetime(df_samsung_electron['DATE'])
# Out:
# <ipython-input-85-219709a81192>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_samsung_electron['DATE'] = pd.to_datetime(df_samsung_electron['DATE'])

# %%
## 삼성전자 df DATE 오름차순 변경.
df_samsung_electron = df_samsung_electron.sort_values('DATE')

# %%
df_samsung_electron
# Out:
#          ID       DATE                                              TITLE  \
# 54500  4431 2001-11-21  부호분할 다중접속 이동통신시스템에서의 부호화 장치 및 방법(CODING APPARA...
# 63921  3838 2002-02-12  기판 사이에 배치된 중합 개시 및 강화 요소로 구성된전기광학식 디스플레이(ELECT...
# 46721  1659 2002-02-12  기판 사이에 배치된 폴리머 코팅 요소로 구성된 전기광학디스플레이(ELECTROOPT...
# 56451  1375 2002-04-04      온도보상기능을 가진 멀티비트 플래쉬메모리(MUIT-BIT FLASH MEMORY)
# 34257  4216 2002-07-23  전자기기의 전원 제어장치(Power supply controlling device ...
# ...     ...        ...                                                ...
# 28238  3204 2021-08-27  이동 통신 시스템에서 복수의 캐리어를 이용하는 데이터 송수신 방법 및 장치(METH...
# 47104  2042 2021-08-30  발광 나노결정 입자, 그의 제조방법 및 발광 나노결정 입자를 포함하는 소자(EMIS...
# 27374  2340 2021-08-31  무선통신 시스템에서 다중 기지국과 랜덤 엑세스 수행 방법 및 장치(METHOD AN...
# 34683  4642 2021-09-07  안테나 및 이를 포함하는 전자 장치(ANTENNA AND ELECTRONIC DEV...
# 47445  2383 2021-09-07  굽은 영역을 갖는 디스플레이를 포함하는 전자 장치(ELECTRONIC DEVICE ...
#
#                          AUTHOR            AUTHOR_RECODED    종목코드
# ...

# %%
df[df['AUTHOR'].str.contains('삼성에스디아이',na=False)]
# Out:
#          ID       DATE                                              TITLE  \
# 93       94 2006-10-27            파우치형 이차전지(Pouch type secondary battery)
# 118     119 2010-11-02  리튬 이차전지용 양극 활물질 및 이의 제조방법(POSITIVE ACTIVE MATE...
# 183     184 2014-07-03  리튬 이차전지용 전해질, 및 이를 포함하는 리튬 이차전지(Electrolyte fo...
# 218     219 2020-02-25              전고체 이차전지(All Solid secondary battery)
# 270     271 2017-07-17                  이차전지 모듈(Secondary Battery Module)
# ...     ...        ...                                                ...
# 52485  2416 2003-07-25  다결정 실리콘 박막 트랜지스터를 포함하는 평판 표시 소자(FLAT PANEL DIS...
# 52486  2417 2002-07-08  티에프티용 다결정 실리콘 박막 및 이를 사용한 디바이스(POLYSILICON THI...
# 52487  2418 2002-01-30  투명도전막의 투과도 변형방법(Method of Varying Transmittanc...
# 52488  2419 2001-11-27  박막 트랜지스터용 다결정 실리콘 박막 및 이를 사용한디바이스(POLYSILICON ...
# 52489  2420 2003-07-25  다결정 실리콘 박막 트랜지스터를 포함하는 평판 표시 소자(FLAT PANEL DIS...
#
#                              AUTHOR                AUTHOR_RECODED
# ...
